# %% [markdown]
# ---
# ---
# ---
# ## **4. Preprocesamiento**
# ---
# ---
# ---

# %%
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# Cargar datos
data = pd.read_csv('C:/Users/er_ja/Desktop/Jaime/Master/Preprocesamiento y Clasificación/Proyecto final/training_set_features.csv', index_col="respondent_id")
labels = pd.read_csv('C:/Users/er_ja/Desktop/Jaime/Master/Preprocesamiento y Clasificación/Proyecto final/training_set_labels.csv', index_col="respondent_id")

# %% [markdown]
# En primer lugar debemos hacer una partición de los datos en un conjunto de entrenamiento y otro de test. Dado que se pretende optimizar el modelo para predecir un conjunto de datos de tamaño similar al que se está usando en este caso, en la división de los datos nos aseguraremos que las instancias de entrenamiento sean el $80\%$ del conjunto total. Esta estrategia nos asegura que los modelos de clasificación son capaces de capturar mayor información.

# %%
# Dividir datos antes del preprocesamiento
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
print(X_train.shape)
# Out:
# (21365, 35)

# %% [markdown]
# ---
# ---
# ### **4.1. Tratamiento de Outliers**
# ---
# ---
#
# Para realizar un correcto preprocesamiento de los datos, es necesario hallar los valores nulos, anómalos, duplicados. Como ya se ha visto en el EDA, no es necesario realizar contrastes para la detección de valores anómalos por las características de los mismos. Todas las variables contienen valores dentro del rango permitido, tal y como se describe en la sección 2.2. Pasamos directamente con la sección de datos faltantes.

# %% [markdown]
# ---
# ---
# ### **4.2. Tratamiento de los valores nulos y duplicados**
# ---
# ---
#
# En esta sección se van a profundizar en los mecanismos para detectar el tipo de valores perdidos que puede presentar el dataset. Ya se han visto anteriormente algunas de las posibles causas para estudiar la influencia de valores perdidos sobre ciertas variables, de este análisis se ha concluido que la variable `Health Insurance` podría ser eliminada, debido a que la presencia de valores nulos no tiene correlación con que el individuo no tenga trabajo y con otras variables que aparecen con una proporción de valores nulos mayor. Sin embago vamos
#
# Una vez eliminada esta columna podemos pasar con las siguientes que mayor proporción de valores perdidos tienen, `employment_industry` y `employment_occupation`. Ya hemos visto que la presencia de valores nulos en estas variables está altamente correlacionada con situaciones laborales de desempleo (`Unemployed` o `Not in Labor Force`). Asímismo, los registros faltantes en `employment_status` parecen tener el mismo perfil de comportamiento y de respuesta que los anteriores, por lo que parece lógico tratarlos de la misma manera.
#
# De manera previa a la eliminación de registros que aportan mayor ruido. Recordemos que en el EDA se exploró el promedio de preguntas no respondidas en cada registro, obteniendo el siguiente gráfico:

# %%
# Calcular la proporción de valores nulos por fila
missing_ratio_per_row = X_train.isna().mean(axis=1) * 100

# Añadir esta proporción como una nueva columna al DataFrame
X_train['missing_ratio'] = missing_ratio_per_row

# Filtrar las filas con más del 40% de valores nulos
rows_with_most_missing = X_train[X_train['missing_ratio'] > 50]

print(f"Total de filas con más del 50% de valores nulos: {len(rows_with_most_missing)}")
print(f"Total de filas con más del 40% de valores nulos: {len(X_train[X_train['missing_ratio'] > 40])} (13 preguntas sin contestar)")
print(f"Total de filas con más del 35% de valores nulos: {len(X_train[X_train['missing_ratio'] > 35])} (11 preguntas sin contestar)")
print(f"Total de filas con más del 30% de valores nulos: {len(X_train[X_train['missing_ratio'] > 30])} (9 preguntas sin contestar)")
print(f"Total de filas con más del 50% de valores nulos: {len(X_train[X_train['missing_ratio'] > 25])} (8 preguntas sin contestar)")
print(f"Total de filas con más del 20% de valores nulos: {len(X_train[X_train['missing_ratio'] > 20])} (6 preguntas sin contestar)")

rows_with_most_missing_sorted = rows_with_most_missing.sort_values(by='missing_ratio', ascending=False)
print(rows_with_most_missing_sorted.head(8))
# Out:
# Total de filas con más del 50% de valores nulos: 160
# Total de filas con más del 40% de valores nulos: 343 (13 preguntas sin contestar)
# Total de filas con más del 35% de valores nulos: 456 (11 preguntas sin contestar)
# Total de filas con más del 30% de valores nulos: 626 (9 preguntas sin contestar)
# Total de filas con más del 50% de valores nulos: 726 (8 preguntas sin contestar)
# Total de filas con más del 20% de valores nulos: 1013 (6 preguntas sin contestar)
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 12629                   NaN             0.0                        0.0
# 6040                    1.0             1.0                        0.0
# 22607                   0.0             0.0                        0.0
# 15425                   1.0             1.0                        0.0
# 20432                   0.0             0.0                        0.0
# 19463                   2.0             1.0                        0.0
# 7878                    2.0             1.0                        0.0
# 3772                    2.0             0.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 12629                           0.0                   0.0
# 6040                            NaN                   0.0
# 22607                           1.0                   0.0
# 15425                           1.0                   0.0
# 20432                           1.0                   0.0
# 19463                           1.0                   0.0
# 7878                            1.0                   0.0
# 3772                            1.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 12629                            1.0                          0.0
# 6040                             1.0                          0.0
# 22607                            1.0                          1.0
# 15425                            1.0                          0.0
# 20432                            1.0                          0.0
# 19463                            1.0                          0.0
# 7878                             1.0                          0.0
# 3772                             0.0                          1.0
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 12629                              0.0                    1.0
# 6040                               0.0                    1.0
# 22607                              0.0                    1.0
# 15425                              0.0                    0.0
# 20432                              0.0                    1.0
# 19463                              0.0                    1.0
# 7878                               1.0                    1.0
# 3772                               0.0                    0.0
#
#                doctor_recc_h1n1  ...  marital_status  rent_or_own  \
# respondent_id                    ...
# 12629                       NaN  ...             NaN          NaN
# 6040                        NaN  ...             NaN          NaN
# 22607                       NaN  ...             NaN          NaN
# 15425                       NaN  ...             NaN          NaN
# 20432                       NaN  ...             NaN          NaN
# 19463                       NaN  ...             NaN          NaN
# 7878                        NaN  ...             NaN          NaN
# 3772                        NaN  ...             NaN          NaN
#
#                employment_status  hhs_geo_region                census_msa  \
# respondent_id
# 12629                        NaN        lzgpxyit                   Non-MSA
# 6040                         NaN        lrircsnp                   Non-MSA
# 22607                        NaN        lzgpxyit       MSA, Principle City
# 15425                        NaN        lzgpxyit  MSA, Not Principle  City
# 20432                        NaN        dqpwygqj  MSA, Not Principle  City
# 19463                        NaN        fpwskwrf       MSA, Principle City
# 7878                         NaN        lzgpxyit       MSA, Principle City
# 3772                         NaN        kbazzjca  MSA, Not Principle  City
#
#                household_adults  household_children  employment_industry  \
# respondent_id
# 12629                       NaN                 NaN                  NaN
# 6040                        NaN                 NaN                  NaN
# 22607                       NaN                 NaN                  NaN
# 15425                       NaN                 NaN                  NaN
# 20432                       NaN                 NaN                  NaN
# 19463                       NaN                 NaN                  NaN
# 7878                        NaN                 NaN                  NaN
# 3772                        NaN                 NaN                  NaN
#
#                employment_occupation  missing_ratio
# respondent_id
# 12629                            NaN      62.857143
# 6040                             NaN      62.857143
# 22607                            NaN      60.000000
# 15425                            NaN      60.000000
# 20432                            NaN      60.000000
# 19463                            NaN      60.000000
# 7878                             NaN      60.000000
# 3772                             NaN      60.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# Se pueden visualizar los resultados más influyentes mediante un gráfico de barras, aunque ya vemos que de 21000 registros separados para el entrenamiento, menos del $3\%$ de los individuos tienen una tasa de no respuesta superior al $30\%$ de las preguntas que se les hacen (629 filas). En estos casos debe ser el analista que, en última instancia, tome la decisión del tipo de filtro que hacer y, por ese mismo motivo, podemos decidir que las observaciones que serán consideradas ruidosas son aquellas con una tasa de respuesta por encima del 35% (E)

# %%
# Visualizar las primeras 200 filas con mayor proporción de valores nulos
plt.figure(figsize=(10, 6))
rows_with_most_missing_sorted['missing_ratio'].plot(kind='bar', color='skyblue')

plt.title('Top Filas con Mayor Proporción de Valores Nulos')
plt.ylabel('Porcentaje de Valores Nulos')
plt.xticks([])
plt.show()

# %%
# Eliminar las filas de 'X_train' que están en 'rows_with_most_missing'
X_train_cleaned = X_train.drop(X_train[X_train['missing_ratio'] > 35].index)

# Identificar las columnas con valores nulos en el DataFrame original (joined_df)
columns_with_nulls = X_train.columns[X_train.isna().any()]

# Crear una matriz de correlación solo para columnas con valores nulos
missing_corr = X_train_cleaned[columns_with_nulls].isna().corr()

# Crear el heatmap de correlación
plt.figure(figsize=(10,10))  # Tamaño adecuado para evitar superposición

g = sns.heatmap(missing_corr, vmax=.3, center=0, 
                square=True, linewidths=1, fmt='.2f', cmap='PuOr')

# Ajustar los márgenes de la figura
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05)

# Rotar las etiquetas de los ejes para mayor legibilidad
plt.xticks(rotation=90, ha='right', fontsize=10)  # Rotar etiquetas del eje X
plt.yticks(rotation=0, ha='right', fontsize=10)   # Etiquetas del eje Y

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Eliminamos la columna que se ha añadido de missing ratio

# %%
X_train.drop(columns=['missing_ratio'], inplace=True)

# %%
def preprocess_data(df, indices_to_keep=None):
    # **Paso 0: Eliminar filas con más del 30% de valores faltantes**
    if indices_to_keep is None:  # Si no se pasan índices, procesamos el conjunto de entrenamiento
        missing_threshold = 0.3
        missing_rate = df.isnull().mean(axis=1)  # Tasa de valores perdidos por fila
        indices_to_keep = missing_rate[missing_rate <= missing_threshold].index  # Índices de filas a conservar
    df = df.loc[indices_to_keep]  # Filtrar filas según índices

    # **Paso 1: Imputación y transformación de columnas específicas**
    df['employment_status'] = df['employment_status'].fillna('Unemployed')
    df[['employment_industry', 'employment_occupation']] = df[['employment_industry', 'employment_occupation']].mask(
        df['employment_status'].isin(['Not in Labor Force', 'Unemployed']), 'Missing'
    )
    df['health_insurance_Missing'] = df['health_insurance'].isna().astype(int)
    df['health_insurance'] = df['health_insurance'].fillna(0).astype(int)

    # **Paso 2: Imputación personalizada**
    ordinal_cols = ['h1n1_concern', 'h1n1_knowledge', 'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk',
                    'opinion_h1n1_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 
                    'opinion_seas_sick_from_vacc']
    for col in ordinal_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')
        max_value = df[col].max()
        df[col] = df[col].fillna(max_value + 1)

    ordinal_order = {
        'age_group': ['18 - 34 Years', '35 - 44 Years', '45 - 54 Years', '55 - 64 Years', '65+ Years'],
        'education': ['< 12 Years', '12 Years', 'Some College', 'College Graduate', 'Missing'],
        'income_poverty': ['Below Poverty', '<= $75,000, Above Poverty', '> $75,000', 'Missing']
    }
    for col, order in ordinal_order.items():
        df[col] = df[col].fillna('Missing')
        df[col] = pd.Categorical(df[col], categories=order, ordered=True).codes

    binary_cols = [
        'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask',
        'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home',
        'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
        'chronic_med_condition', 'child_under_6_months', 'health_worker'
    ]
    for col in binary_cols:
        df[col] = df[col].fillna(df[col].mean()).round(0).astype(int)

    binary_cols_str = ['sex', 'marital_status', 'rent_or_own']
    mappings = {
        'sex': {'Male': 0, 'Female': 1},
        'marital_status': {'Not Married': 0, 'Married': 1},
        'rent_or_own': {'Own': 0, 'Rent': 1}
    }
    for col, mapping in mappings.items():
        df[col] = df[col].fillna('Missing')
        df[col] = df[col].map(mapping).fillna(-1).astype(int)

    nominal_cols = ['race', 'employment_status', 'hhs_geo_region', 'census_msa', 
                    'employment_industry', 'employment_occupation']
    for col in nominal_cols:
        df[col] = df[col].fillna('Missing')

    one_hot_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
    nominal_encoded = one_hot_encoder.fit_transform(df[nominal_cols])
    nominal_encoded_df = pd.DataFrame(
        nominal_encoded,
        columns=one_hot_encoder.get_feature_names_out(nominal_cols),
        index=df.index
    )

    numeric_cols = ['household_adults', 'household_children']
    imputer = KNNImputer(n_neighbors=5)
    df[numeric_cols] = imputer.fit_transform(df[numeric_cols])
    df[numeric_cols] = df[numeric_cols].round(0).astype(int)

    df.drop(columns=nominal_cols, inplace=True)
    df = pd.concat([df, nominal_encoded_df], axis=1)

    return df, indices_to_keep

# %%
X_train_preprocessed, indices_to_keep_train = preprocess_data(X_train.copy())
X_test_preprocessed, indices_to_keep_test = preprocess_data(X_test.copy())

# %%
X_train_preprocessed.to_csv('preprocessed_X_train.csv', index=True)
X_test_preprocessed.to_csv('preprocessed_X_test.csv', index=True)
y_train.loc[indices_to_keep_train].to_csv('preprocessed_y_train.csv', index=True)
y_test.loc[indices_to_keep_test].to_csv('preprocessed_y_test.csv', index=True)

# %%
print(X_train_preprocessed.columns)
# Out:
# Index(['h1n1_concern', 'h1n1_knowledge', 'behavioral_antiviral_meds',
#        'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk',
#        'opinion_h1n1_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
#        'education', 'sex', 'income_poverty', 'marital_status', 'rent_or_own',
#        'household_adults', 'household_children', 'health_insurance_Missing',
#        'race_Black', 'race_Hispanic', 'race_Other or Multiple', 'race_White',
#        'employment_status_Employed', 'employment_status_Not in Labor Force',
#        'employment_status_Unemployed', 'hhs_geo_region_atmpeygn',
#        'hhs_geo_region_bhuqouqj', 'hhs_geo_region_dqpwygqj',
#        'hhs_geo_region_fpwskwrf', 'hhs_geo_region_kbazzjca',
#        'hhs_geo_region_lrircsnp', 'hhs_geo_region_lzgpxyit',
#        'hhs_geo_region_mlyzmhmf', 'hhs_geo_region_oxchjgsf',
#        'hhs_geo_region_qufhixun', 'census_msa_MSA, Not Principle  City',
#        'census_msa_MSA, Principle City', 'census_msa_Non-MSA',
#        'employment_industry_Missing', 'employment_industry_arjwrbjb',
#        'employment_industry_atmlpfrs', 'employment_industry_cfqqtusy',
#        'employment_industry_dotnnunm', 'employment_industry_fcxhlnwr',
#        'employment_industry_haxffmxo', 'employment_industry_ldnlellj',
#        'employment_industry_mcubkhph', 'employment_industry_mfikgejo',
#        'employment_industry_msuufmds', 'employment_industry_nduyfdeo',
#        'employment_industry_phxvnwax', 'employment_industry_pxcmvdjn',
#        'employment_industry_qnlwzans', 'employment_industry_rucpziij',
#        'employment_industry_saaquncn', 'employment_industry_vjjrobsf',
#        'employment_industry_wlfvacwt', 'employment_industry_wxleyezf',
#        'employment_industry_xicduogh', 'employment_industry_xqicxuve',
#        'employment_occupation_Missing', 'employment_occupation_bxpfxfdn',
#        'employment_occupation_ccgxvspp', 'employment_occupation_cmhcxjea',
#        'employment_occupation_dcjcmpih', 'employment_occupation_dlvbwzss',
#        'employment_occupation_emcorrxb', 'employment_occupation_haliazsg',
#        'employment_occupation_hfxkjkmi', 'employment_occupation_hodpvpew',
#        'employment_occupation_kldqjyjy', 'employment_occupation_mxkfnird',
#        'employment_occupation_oijqvulv', 'employment_occupation_pvmttkik',
#        'employment_occupation_qxajmpny', 'employment_occupation_rcertsgn',
#        'employment_occupation_tfqavkke', 'employment_occupation_ukymxvdu',
#        'employment_occupation_uqqtjvyb', 'employment_occupation_vlluhbov',
#        'employment_occupation_xgwztkwe', 'employment_occupation_xqwwgdyp',
#        'employment_occupation_xtkaffoo', 'employment_occupation_xzmlyyjv'],
#       dtype='object')

# %%
# Cargar el conjunto de prueba externo y preprocesar
test_set_features = pd.read_csv("C:/Users/er_ja/Desktop/Jaime/Master/Preprocesamiento y Clasificación/Proyecto final/test_set_features.csv", index_col="respondent_id")
test_set_preprocessed = preprocess_data(test_set_features.copy())

# Guardar el conjunto de prueba preprocesado
test_set_preprocessed.to_csv("C:/Users/er_ja/Desktop/Jaime/Master/Preprocesamiento y Clasificación/Proyecto final/preprocessed_test_set_features.csv", index=True)

# %%
print(X_train_preprocessed.isnull().sum())
# Out:
# h1n1_concern                      0
# h1n1_knowledge                    0
# behavioral_antiviral_meds         0
# behavioral_avoidance              0
# behavioral_face_mask              0
#                                  ..
# employment_occupation_vlluhbov    0
# employment_occupation_xgwztkwe    0
# employment_occupation_xqwwgdyp    0
# employment_occupation_xtkaffoo    0
# employment_occupation_xzmlyyjv    0
# Length: 96, dtype: int64

# %%
print(X_train_preprocessed.shape)
print(y_train.loc[indices_to_keep_train].shape)
print(X_test_preprocessed.shape)
print(y_test.loc[indices_to_keep_test].shape)
# Out:
# (20739, 96)
# (20739, 2)
# (5195, 96)
# (5195, 2)

# %%
# 1. Dimensiones del dataset
print("Dimensiones del dataset:")
print(f"Filas: {X_train_preprocessed.shape[0]}, Columnas: {X_train_preprocessed.shape[1]}")

# 2. Información del dataset
print("\nInformación general del dataset:")
print(X_train_preprocessed.info())

# 3. Valores faltantes
print("\nValores faltantes por columna (porcentaje):")
missing_values = X_train_preprocessed.isna().mean() * 100
print(missing_values[missing_values > 0])

# 4. Estadísticas descriptivas
print("\nEstadísticas descriptivas del dataset:")
print(X_train_preprocessed.describe())

# 5. Distribución de las variables categóricas (opcional)
print("\nDistribución de algunas variables categóricas:")
categorical_cols = [col for col in X_train_preprocessed.columns if X_train_preprocessed[col].dtype == 'object']
for col in categorical_cols:
    print(f"\nDistribución de '{col}':")
    print(X_train_preprocessed[col].value_counts(normalize=True) * 100)
# Out:
# Dimensiones del dataset:
# Filas: 20739, Columnas: 96
#
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20739 entries, 12230 to 467
# Data columns (total 96 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   h1n1_concern                          20739 non-null  float64
#  1   h1n1_knowledge                        20739 non-null  float64
#  2   behavioral_antiviral_meds             20739 non-null  int64
#  3   behavioral_avoidance                  20739 non-null  int64
#  4   behavioral_face_mask                  20739 non-null  int64
#  5   behavioral_wash_hands                 20739 non-null  int64
#  6   behavioral_large_gatherings           20739 non-null  int64
#  7   behavioral_outside_home               20739 non-null  int64
#  8   behavioral_touch_face                 20739 non-null  int64
#  9   doctor_recc_h1n1                      20739 non-null  int64
#  10  doctor_recc_seasonal                  20739 non-null  int64
#  11  chronic_med_condition                 20739 non-null  int64
#  12  child_under_6_months                  20739 non-null  int64
#  13  health_worker                         20739 non-null  int64
#  14  health_insurance                      20739 non-null  int64
#  15  opinion_h1n1_vacc_effective           20739 non-null  float64
#  16  opinion_h1n1_risk                     20739 non-null  float64
#  17  opinion_h1n1_sick_from_vacc           20739 non-null  float64
#  18  opinion_seas_vacc_effective           20739 non-null  float64
#  19  opinion_seas_risk                     20739 non-null  float64
#  20  opinion_seas_sick_from_vacc           20739 non-null  float64
#  21  age_group                             20739 non-null  int8
#  22  education                             20739 non-null  int8
#  23  sex                                   20739 non-null  int64
#  24  income_poverty                        20739 non-null  int8
#  25  marital_status                        20739 non-null  int64
#  26  rent_or_own                           20739 non-null  int64
#  27  household_adults                      20739 non-null  int64
#  28  household_children                    20739 non-null  int64
#  29  health_insurance_Missing              20739 non-null  int64
#  30  race_Black                            20739 non-null  float64
#  31  race_Hispanic                         20739 non-null  float64
#  32  race_Other or Multiple                20739 non-null  float64
#  33  race_White                            20739 non-null  float64
#  34  employment_status_Employed            20739 non-null  float64
#  35  employment_status_Not in Labor Force  20739 non-null  float64
#  36  employment_status_Unemployed          20739 non-null  float64
#  37  hhs_geo_region_atmpeygn               20739 non-null  float64
#  38  hhs_geo_region_bhuqouqj               20739 non-null  float64
#  39  hhs_geo_region_dqpwygqj               20739 non-null  float64
#  40  hhs_geo_region_fpwskwrf               20739 non-null  float64
#  41  hhs_geo_region_kbazzjca               20739 non-null  float64
#  42  hhs_geo_region_lrircsnp               20739 non-null  float64
#  43  hhs_geo_region_lzgpxyit               20739 non-null  float64
#  44  hhs_geo_region_mlyzmhmf               20739 non-null  float64
#  45  hhs_geo_region_oxchjgsf               20739 non-null  float64
#  46  hhs_geo_region_qufhixun               20739 non-null  float64
#  47  census_msa_MSA, Not Principle  City   20739 non-null  float64
#  48  census_msa_MSA, Principle City        20739 non-null  float64
#  49  census_msa_Non-MSA                    20739 non-null  float64
#  50  employment_industry_Missing           20739 non-null  float64
#  51  employment_industry_arjwrbjb          20739 non-null  float64
#  52  employment_industry_atmlpfrs          20739 non-null  float64
#  53  employment_industry_cfqqtusy          20739 non-null  float64
#  54  employment_industry_dotnnunm          20739 non-null  float64
#  55  employment_industry_fcxhlnwr          20739 non-null  float64
#  56  employment_industry_haxffmxo          20739 non-null  float64
#  57  employment_industry_ldnlellj          20739 non-null  float64
#  58  employment_industry_mcubkhph          20739 non-null  float64
#  59  employment_industry_mfikgejo          20739 non-null  float64
#  60  employment_industry_msuufmds          20739 non-null  float64
#  61  employment_industry_nduyfdeo          20739 non-null  float64
#  62  employment_industry_phxvnwax          20739 non-null  float64
#  63  employment_industry_pxcmvdjn          20739 non-null  float64
#  64  employment_industry_qnlwzans          20739 non-null  float64
#  65  employment_industry_rucpziij          20739 non-null  float64
#  66  employment_industry_saaquncn          20739 non-null  float64
#  67  employment_industry_vjjrobsf          20739 non-null  float64
#  68  employment_industry_wlfvacwt          20739 non-null  float64
#  69  employment_industry_wxleyezf          20739 non-null  float64
#  70  employment_industry_xicduogh          20739 non-null  float64
#  71  employment_industry_xqicxuve          20739 non-null  float64
#  72  employment_occupation_Missing         20739 non-null  float64
#  73  employment_occupation_bxpfxfdn        20739 non-null  float64
#  74  employment_occupation_ccgxvspp        20739 non-null  float64
#  75  employment_occupation_cmhcxjea        20739 non-null  float64
#  76  employment_occupation_dcjcmpih        20739 non-null  float64
#  77  employment_occupation_dlvbwzss        20739 non-null  float64
#  78  employment_occupation_emcorrxb        20739 non-null  float64
#  79  employment_occupation_haliazsg        20739 non-null  float64
#  80  employment_occupation_hfxkjkmi        20739 non-null  float64
#  81  employment_occupation_hodpvpew        20739 non-null  float64
#  82  employment_occupation_kldqjyjy        20739 non-null  float64
#  83  employment_occupation_mxkfnird        20739 non-null  float64
#  84  employment_occupation_oijqvulv        20739 non-null  float64
#  85  employment_occupation_pvmttkik        20739 non-null  float64
#  86  employment_occupation_qxajmpny        20739 non-null  float64
#  87  employment_occupation_rcertsgn        20739 non-null  float64
#  88  employment_occupation_tfqavkke        20739 non-null  float64
#  89  employment_occupation_ukymxvdu        20739 non-null  float64
#  90  employment_occupation_uqqtjvyb        20739 non-null  float64
#  91  employment_occupation_vlluhbov        20739 non-null  float64
#  92  employment_occupation_xgwztkwe        20739 non-null  float64
#  93  employment_occupation_xqwwgdyp        20739 non-null  float64
#  94  employment_occupation_xtkaffoo        20739 non-null  float64
#  95  employment_occupation_xzmlyyjv        20739 non-null  float64
# dtypes: float64(74), int64(19), int8(3)
# memory usage: 14.9 MB
# None
#
# Valores faltantes por columna (porcentaje):
# Series([], dtype: float64)
#
# Estadísticas descriptivas del dataset:
#        h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# count  20739.000000    20739.000000               20739.000000
# mean       1.625585        1.279329                   0.047881
# std        0.915982        0.620356                   0.213519
# min        0.000000        0.000000                   0.000000
# 25%        1.000000        1.000000                   0.000000
# 50%        2.000000        1.000000                   0.000000
# 75%        2.000000        2.000000                   0.000000
# max        4.000000        3.000000                   1.000000
#
#        behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# count          20739.000000          20739.000000           20739.000000
# mean               0.730508              0.069242               0.825835
# std                0.443707              0.253871               0.379260
# min                0.000000              0.000000               0.000000
# 25%                0.000000              0.000000               1.000000
# 50%                1.000000              0.000000               1.000000
# 75%                1.000000              0.000000               1.000000
# max                1.000000              1.000000               1.000000
#
#        behavioral_large_gatherings  behavioral_outside_home  \
# count                 20739.000000             20739.000000
# mean                      0.353826                 0.331405
# std                       0.478168                 0.470730
# min                       0.000000                 0.000000
# 25%                       0.000000                 0.000000
# 50%                       0.000000                 0.000000
# 75%                       1.000000                 1.000000
# max                       1.000000                 1.000000
#
#        behavioral_touch_face  doctor_recc_h1n1  ...  \
# count           20739.000000      20739.000000  ...
# mean                0.677998          0.203481  ...
# std                 0.467255          0.402597  ...
# min                 0.000000          0.000000  ...
# 25%                 0.000000          0.000000  ...
# 50%                 1.000000          0.000000  ...
# 75%                 1.000000          0.000000  ...
# max                 1.000000          1.000000  ...
#
#        employment_occupation_qxajmpny  employment_occupation_rcertsgn  \
# count                    20739.000000                    20739.000000
# mean                         0.021313                        0.010656
# std                          0.144427                        0.102680
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_tfqavkke  employment_occupation_ukymxvdu  \
# count                    20739.000000                    20739.000000
# mean                         0.014562                        0.014755
# std                          0.119794                        0.120573
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_uqqtjvyb  employment_occupation_vlluhbov  \
# count                    20739.000000                    20739.000000
# mean                         0.017166                        0.013887
# std                          0.129892                        0.117024
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_xgwztkwe  employment_occupation_xqwwgdyp  \
# count                    20739.000000                    20739.000000
# mean                         0.041661                        0.017985
# std                          0.199817                        0.132902
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_xtkaffoo  employment_occupation_xzmlyyjv
# count                    20739.000000                    20739.000000
# mean                         0.069145                        0.009306
# std                          0.253707                        0.096021
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
# [8 rows x 96 columns]
#
# Distribución de algunas variables categóricas:

# %%
# 6. Correlación entre variables (opcional)
print("\nMatriz de correlación:")
correlation_matrix = X_train_preprocessed.corr()
print(correlation_matrix)

# Visualización opcional de correlaciones altas
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Matriz de correlación del dataset preprocesado")
plt.show()
# Out:
# Matriz de correlación:
#                                 h1n1_concern  h1n1_knowledge  \
# h1n1_concern                        1.000000        0.053037
# h1n1_knowledge                      0.053037        1.000000
# behavioral_antiviral_meds           0.088708       -0.008509
# behavioral_avoidance                0.221676        0.077987
# behavioral_face_mask                0.158978        0.035175
# ...                                      ...             ...
# employment_occupation_vlluhbov      0.017019       -0.040150
# employment_occupation_xgwztkwe     -0.024108        0.014261
# employment_occupation_xqwwgdyp      0.003033       -0.035788
# employment_occupation_xtkaffoo     -0.017033        0.068458
# employment_occupation_xzmlyyjv     -0.010821        0.030834
#
#                                 behavioral_antiviral_meds  \
# h1n1_concern                                     0.088708
# h1n1_knowledge                                  -0.008509
# behavioral_antiviral_meds                        1.000000
# behavioral_avoidance                             0.044081
# behavioral_face_mask                             0.144328
# ...                                                   ...
# employment_occupation_vlluhbov                   0.031283
# employment_occupation_xgwztkwe                   0.007494
# employment_occupation_xqwwgdyp                   0.020630
# employment_occupation_xtkaffoo                  -0.013051
# employment_occupation_xzmlyyjv                  -0.009975
#
#                                 behavioral_avoidance  behavioral_face_mask  \
# h1n1_concern                                0.221676              0.158978
# h1n1_knowledge                              0.077987              0.035175
# behavioral_antiviral_meds                   0.044081              0.144328
# behavioral_avoidance                        1.000000              0.060355
# behavioral_face_mask                        0.060355              1.000000
# ...                                              ...                   ...
# employment_occupation_vlluhbov             -0.001287              0.022818
# employment_occupation_xgwztkwe              0.002089             -0.026450
# employment_occupation_xqwwgdyp             -0.015111             -0.009757
# employment_occupation_xtkaffoo              0.012188             -0.027920
# employment_occupation_xzmlyyjv             -0.003382             -0.004676
#
#                                 behavioral_wash_hands  \
# h1n1_concern                                 0.278947
# h1n1_knowledge                               0.080943
# behavioral_antiviral_meds                    0.060705
# behavioral_avoidance                         0.328843
# behavioral_face_mask                         0.080182
# ...                                               ...
# employment_occupation_vlluhbov               0.004519
# employment_occupation_xgwztkwe              -0.004786
# employment_occupation_xqwwgdyp              -0.001948
# employment_occupation_xtkaffoo              -0.002630
# employment_occupation_xzmlyyjv              -0.007132
#
#                                 behavioral_large_gatherings  \
# h1n1_concern                                       0.250296
# h1n1_knowledge                                    -0.045470
# behavioral_antiviral_meds                          0.101851
# behavioral_avoidance                               0.224217
# behavioral_face_mask                               0.176332
# ...                                                     ...
# employment_occupation_vlluhbov                     0.024213
# employment_occupation_xgwztkwe                    -0.044264
# employment_occupation_xqwwgdyp                     0.015952
# employment_occupation_xtkaffoo                    -0.051032
# employment_occupation_xzmlyyjv                    -0.039162
#
#                                 behavioral_outside_home  \
# h1n1_concern                                   0.242832
# h1n1_knowledge                                -0.065692
# behavioral_antiviral_meds                      0.123738
# behavioral_avoidance                           0.220069
# behavioral_face_mask                           0.162251
# ...                                                 ...
# employment_occupation_vlluhbov                 0.024996
# employment_occupation_xgwztkwe                -0.042209
# employment_occupation_xqwwgdyp                 0.023421
# employment_occupation_xtkaffoo                -0.054603
# employment_occupation_xzmlyyjv                -0.041565
#
#                                 behavioral_touch_face  doctor_recc_h1n1  ...  \
# h1n1_concern                                 0.241179          0.133641  ...
# h1n1_knowledge                               0.078746          0.089438  ...
# behavioral_antiviral_meds                    0.065611          0.047088  ...
# behavioral_avoidance                         0.326162          0.068094  ...
# behavioral_face_mask                         0.105446          0.080111  ...
# ...                                               ...               ...  ...
# employment_occupation_vlluhbov               0.003295         -0.011875  ...
# employment_occupation_xgwztkwe              -0.011771         -0.019066  ...
# employment_occupation_xqwwgdyp              -0.006906         -0.030550  ...
# employment_occupation_xtkaffoo              -0.024507         -0.006511  ...
# employment_occupation_xzmlyyjv              -0.019188         -0.020297  ...
#
#                                 employment_occupation_qxajmpny  \
# h1n1_concern                                         -0.022784
# h1n1_knowledge                                       -0.052455
# behavioral_antiviral_meds                             0.021636
# behavioral_avoidance                                 -0.028507
# behavioral_face_mask                                 -0.003426
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.017512
# employment_occupation_xgwztkwe                       -0.030768
# employment_occupation_xqwwgdyp                       -0.019971
# employment_occupation_xtkaffoo                       -0.040219
# employment_occupation_xzmlyyjv                       -0.014302
#
#                                 employment_occupation_rcertsgn  \
# h1n1_concern                                         -0.028841
# h1n1_knowledge                                       -0.016451
# behavioral_antiviral_meds                             0.003120
# behavioral_avoidance                                 -0.019519
# behavioral_face_mask                                 -0.020908
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.012316
# employment_occupation_xgwztkwe                       -0.021639
# employment_occupation_xqwwgdyp                       -0.014045
# employment_occupation_xtkaffoo                       -0.028286
# employment_occupation_xzmlyyjv                       -0.010059
#
#                                 employment_occupation_tfqavkke  \
# h1n1_concern                                          0.005745
# h1n1_knowledge                                       -0.042408
# behavioral_antiviral_meds                             0.017985
# behavioral_avoidance                                 -0.008721
# behavioral_face_mask                                  0.006484
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.014426
# employment_occupation_xgwztkwe                       -0.025345
# employment_occupation_xqwwgdyp                       -0.016451
# employment_occupation_xtkaffoo                       -0.033131
# employment_occupation_xzmlyyjv                       -0.011782
#
#                                 employment_occupation_ukymxvdu  \
# h1n1_concern                                         -0.020708
# h1n1_knowledge                                        0.029994
# behavioral_antiviral_meds                            -0.018078
# behavioral_avoidance                                 -0.004989
# behavioral_face_mask                                 -0.009748
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.014522
# employment_occupation_xgwztkwe                       -0.025515
# employment_occupation_xqwwgdyp                       -0.016561
# employment_occupation_xtkaffoo                       -0.033353
# employment_occupation_xzmlyyjv                       -0.011861
#
#                                 employment_occupation_uqqtjvyb  \
# h1n1_concern                                         -0.017714
# h1n1_knowledge                                       -0.041555
# behavioral_antiviral_meds                             0.017307
# behavioral_avoidance                                 -0.018458
# behavioral_face_mask                                  0.000512
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.015683
# employment_occupation_xgwztkwe                       -0.027555
# employment_occupation_xqwwgdyp                       -0.017885
# employment_occupation_xtkaffoo                       -0.036019
# employment_occupation_xzmlyyjv                       -0.012809
#
#                                 employment_occupation_vlluhbov  \
# h1n1_concern                                          0.017019
# h1n1_knowledge                                       -0.040150
# behavioral_antiviral_meds                             0.031283
# behavioral_avoidance                                 -0.001287
# behavioral_face_mask                                  0.022818
# ...                                                        ...
# employment_occupation_vlluhbov                        1.000000
# employment_occupation_xgwztkwe                       -0.024742
# employment_occupation_xqwwgdyp                       -0.016060
# employment_occupation_xtkaffoo                       -0.032343
# employment_occupation_xzmlyyjv                       -0.011501
#
#                                 employment_occupation_xgwztkwe  \
# h1n1_concern                                         -0.024108
# h1n1_knowledge                                        0.014261
# behavioral_antiviral_meds                             0.007494
# behavioral_avoidance                                  0.002089
# behavioral_face_mask                                 -0.026450
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.024742
# employment_occupation_xgwztkwe                        1.000000
# employment_occupation_xqwwgdyp                       -0.028217
# employment_occupation_xtkaffoo                       -0.056825
# employment_occupation_xzmlyyjv                       -0.020208
#
#                                 employment_occupation_xqwwgdyp  \
# h1n1_concern                                          0.003033
# h1n1_knowledge                                       -0.035788
# behavioral_antiviral_meds                             0.020630
# behavioral_avoidance                                 -0.015111
# behavioral_face_mask                                 -0.009757
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.016060
# employment_occupation_xgwztkwe                       -0.028217
# employment_occupation_xqwwgdyp                        1.000000
# employment_occupation_xtkaffoo                       -0.036884
# employment_occupation_xzmlyyjv                       -0.013116
#
#                                 employment_occupation_xtkaffoo  \
# h1n1_concern                                         -0.017033
# h1n1_knowledge                                        0.068458
# behavioral_antiviral_meds                            -0.013051
# behavioral_avoidance                                  0.012188
# behavioral_face_mask                                 -0.027920
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.032343
# employment_occupation_xgwztkwe                       -0.056825
# employment_occupation_xqwwgdyp                       -0.036884
# employment_occupation_xtkaffoo                        1.000000
# employment_occupation_xzmlyyjv                       -0.026415
#
#                                 employment_occupation_xzmlyyjv
# h1n1_concern                                         -0.010821
# h1n1_knowledge                                        0.030834
# behavioral_antiviral_meds                            -0.009975
# behavioral_avoidance                                 -0.003382
# behavioral_face_mask                                 -0.004676
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.011501
# employment_occupation_xgwztkwe                       -0.020208
# employment_occupation_xqwwgdyp                       -0.013116
# employment_occupation_xtkaffoo                       -0.026415
# employment_occupation_xzmlyyjv                        1.000000
#
# [96 rows x 96 columns]

# %% [markdown]
# Es obvio que una vez se han codificado todas las variables, resulta casi imposible distinguir correctamente las correlaciones entre variables
