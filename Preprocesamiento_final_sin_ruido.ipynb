# %% [markdown]
# ---
# ---
# ---
# ## **4. Preprocesamiento**
# ---
# ---
# ---

# %%
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# Cargar datos
data = pd.read_csv('Data/training_set_features.csv', index_col="respondent_id")
labels = pd.read_csv('Data/training_set_labels.csv', index_col="respondent_id")

# %% [markdown]
# En primer lugar debemos hacer una partición de los datos en un conjunto de entrenamiento y otro de test. Dado que se pretende optimizar el modelo para predecir un conjunto de datos de tamaño similar al que se está usando en este caso, en la división de los datos nos aseguraremos que las instancias de entrenamiento sean el $80\%$ del conjunto total. Esta estrategia nos asegura que los modelos de clasificación son capaces de capturar mayor información.

# %%
# Dividir datos antes del preprocesamiento
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
print(X_train.shape)
# Out:
# (21365, 35)

# %% [markdown]
# ---
# ---
# ### **4.1. Tratamiento de Outliers**
# ---
# ---
#
# Para realizar un correcto preprocesamiento de los datos, es necesario hallar los valores nulos, anómalos, duplicados. Como ya se ha visto en el EDA, no es necesario realizar contrastes para la detección de valores anómalos por las características de los mismos. Todas las variables contienen valores dentro del rango permitido, tal y como se describe en la sección 2.2. Pasamos directamente con la sección de datos faltantes.

# %% [markdown]
# ---
# ---
# ### **4.2. Tratamiento de los valores nulos y duplicados**
# ---
# ---
#
# En esta sección se van a profundizar en los mecanismos para detectar el tipo de valores perdidos que puede presentar el dataset. Ya se han visto anteriormente algunas de las posibles causas para estudiar la influencia de valores perdidos sobre ciertas variables, de este análisis se ha concluido que la variable `Health Insurance` podría ser eliminada, debido a que la presencia de valores nulos no tiene correlación con que el individuo no tenga trabajo y con otras variables que aparecen con una proporción de valores nulos mayor. Sin embago vamos
#
# Una vez eliminada esta columna podemos pasar con las siguientes que mayor proporción de valores perdidos tienen, `employment_industry` y `employment_occupation`. Ya hemos visto que la presencia de valores nulos en estas variables está altamente correlacionada con situaciones laborales de desempleo (`Unemployed` o `Not in Labor Force`). Asímismo, los registros faltantes en `employment_status` parecen tener el mismo perfil de comportamiento y de respuesta que los anteriores, por lo que parece lógico tratarlos de la misma manera.
#
# De manera previa a la eliminación de registros que aportan mayor ruido. Recordemos que en el EDA se exploró el promedio de preguntas no respondidas en cada registro, obteniendo el siguiente gráfico:

# %%
# Calcular la proporción de valores nulos por fila
missing_ratio_per_row = X_train.isna().mean(axis=1) * 100

# Añadir esta proporción como una nueva columna al DataFrame
X_train['missing_ratio'] = missing_ratio_per_row

# Filtrar las filas con más del 40% de valores nulos
rows_with_most_missing = X_train[X_train['missing_ratio'] > 50]

print(f"Total de filas con más del 50% de valores nulos: {len(rows_with_most_missing)}")
print(f"Total de filas con más del 40% de valores nulos: {len(X_train[X_train['missing_ratio'] > 40])} (13 preguntas sin contestar)")
print(f"Total de filas con más del 35% de valores nulos: {len(X_train[X_train['missing_ratio'] > 35])} (11 preguntas sin contestar)")
print(f"Total de filas con más del 30% de valores nulos: {len(X_train[X_train['missing_ratio'] > 30])} (9 preguntas sin contestar)")
print(f"Total de filas con más del 50% de valores nulos: {len(X_train[X_train['missing_ratio'] > 25])} (8 preguntas sin contestar)")
print(f"Total de filas con más del 20% de valores nulos: {len(X_train[X_train['missing_ratio'] > 20])} (6 preguntas sin contestar)")

rows_with_most_missing_sorted = rows_with_most_missing.sort_values(by='missing_ratio', ascending=False)
print(rows_with_most_missing_sorted.head(8))
# Out:
# Total de filas con más del 50% de valores nulos: 160
# Total de filas con más del 40% de valores nulos: 343 (13 preguntas sin contestar)
# Total de filas con más del 35% de valores nulos: 456 (11 preguntas sin contestar)
# Total de filas con más del 30% de valores nulos: 626 (9 preguntas sin contestar)
# Total de filas con más del 50% de valores nulos: 726 (8 preguntas sin contestar)
# Total de filas con más del 20% de valores nulos: 1013 (6 preguntas sin contestar)
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 6040                    1.0             1.0                        0.0
# 12629                   NaN             0.0                        0.0
# 7749                    2.0             1.0                        0.0
# 21964                   2.0             0.0                        0.0
# 15580                   1.0             1.0                        0.0
# 14266                   2.0             1.0                        0.0
# 4076                    3.0             1.0                        0.0
# 1646                    2.0             2.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 6040                            NaN                   0.0
# 12629                           0.0                   0.0
# 7749                            1.0                   0.0
# 21964                           1.0                   0.0
# 15580                           1.0                   0.0
# 14266                           0.0                   0.0
# 4076                            0.0                   0.0
# 1646                            0.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 6040                             1.0                          0.0
# 12629                            1.0                          0.0
# 7749                             0.0                          1.0
# 21964                            1.0                          1.0
# 15580                            1.0                          0.0
# 14266                            1.0                          0.0
# 4076                             1.0                          1.0
# 1646                             1.0                          0.0
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 6040                               0.0                    1.0
# 12629                              0.0                    1.0
# 7749                               0.0                    1.0
# 21964                              0.0                    0.0
# 15580                              0.0                    1.0
# 14266                              0.0                    1.0
# 4076                               1.0                    1.0
# 1646                               0.0                    0.0
#
#                doctor_recc_h1n1  ...  marital_status  rent_or_own  \
# respondent_id                    ...
# 6040                        NaN  ...             NaN          NaN
# 12629                       NaN  ...             NaN          NaN
# 7749                        NaN  ...             NaN          NaN
# 21964                       NaN  ...             NaN          NaN
# 15580                       NaN  ...             NaN          NaN
# 14266                       NaN  ...             NaN          NaN
# 4076                        NaN  ...             NaN          NaN
# 1646                        NaN  ...             NaN          NaN
#
#                employment_status  hhs_geo_region                census_msa  \
# respondent_id
# 6040                         NaN        lrircsnp                   Non-MSA
# 12629                        NaN        lzgpxyit                   Non-MSA
# 7749                         NaN        lzgpxyit       MSA, Principle City
# 21964                        NaN        lzgpxyit  MSA, Not Principle  City
# 15580                        NaN        lzgpxyit  MSA, Not Principle  City
# 14266                        NaN        lzgpxyit                   Non-MSA
# 4076                         NaN        dqpwygqj       MSA, Principle City
# 1646                         NaN        lrircsnp       MSA, Principle City
#
#                household_adults  household_children  employment_industry  \
# respondent_id
# 6040                        NaN                 NaN                  NaN
# 12629                       NaN                 NaN                  NaN
# 7749                        NaN                 NaN                  NaN
# 21964                       NaN                 NaN                  NaN
# 15580                       NaN                 NaN                  NaN
# 14266                       NaN                 NaN                  NaN
# 4076                        NaN                 NaN                  NaN
# 1646                        NaN                 NaN                  NaN
#
#                employment_occupation  missing_ratio
# respondent_id
# 6040                             NaN      62.857143
# 12629                            NaN      62.857143
# 7749                             NaN      60.000000
# 21964                            NaN      60.000000
# 15580                            NaN      60.000000
# 14266                            NaN      60.000000
# 4076                             NaN      60.000000
# 1646                             NaN      60.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# Se pueden visualizar los resultados más influyentes mediante un gráfico de barras, aunque ya vemos que de 21000 registros separados para el entrenamiento, menos del $3\%$ de los individuos tienen una tasa de no respuesta superior al $30\%$ de las preguntas que se les hacen (629 filas). En estos casos debe ser el analista que, en última instancia, tome la decisión del tipo de filtro que hacer y, por ese mismo motivo, podemos decidir que las observaciones que serán consideradas ruidosas son aquellas con una tasa de respuesta por encima del 35% (E)

# %%
# Visualizar las primeras 200 filas con mayor proporción de valores nulos
plt.figure(figsize=(10, 6))
rows_with_most_missing_sorted['missing_ratio'].plot(kind='bar', color='skyblue')

plt.title('Top Filas con Mayor Proporción de Valores Nulos')
plt.ylabel('Porcentaje de Valores Nulos')
plt.xticks([])
plt.show()

# %%
# Eliminar las filas de 'X_train' que están en 'rows_with_most_missing'
X_train_cleaned = X_train.drop(X_train[X_train['missing_ratio'] > 35].index)

# Identificar las columnas con valores nulos en el DataFrame original (joined_df)
columns_with_nulls = X_train.columns[X_train.isna().any()]

# Crear una matriz de correlación solo para columnas con valores nulos
missing_corr = X_train_cleaned[columns_with_nulls].isna().corr()

# Crear el heatmap de correlación
plt.figure(figsize=(10,10))  # Tamaño adecuado para evitar superposición

g = sns.heatmap(missing_corr, vmax=.3, center=0, 
                square=True, linewidths=1, fmt='.2f', cmap='PuOr')

# Ajustar los márgenes de la figura
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05)

# Rotar las etiquetas de los ejes para mayor legibilidad
plt.xticks(rotation=90, ha='right', fontsize=10)  # Rotar etiquetas del eje X
plt.yticks(rotation=0, ha='right', fontsize=10)   # Etiquetas del eje Y

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Eliminamos la columna que se ha añadido de missing ratio

# %%
X_train.drop(columns=['missing_ratio'], inplace=True)

# %%
def preprocess_data(df, is_train=True, indices_to_keep=None):
    # **Paso 0: Eliminar filas con más del 30% de valores faltantes (solo para entrenamiento)**
    if is_train:  # Si es conjunto de entrenamiento
        missing_threshold = 0.5
        missing_rate = df.isnull().mean(axis=1)  # Tasa de valores perdidos por fila
        indices_to_keep = missing_rate[missing_rate <= missing_threshold].index  # Índices de filas a conservar
        df = df.loc[indices_to_keep]  # Filtrar filas según índices
    elif indices_to_keep is not None:  # Si no es entrenamiento pero hay índices para conservar
        df = df.loc[indices_to_keep]  # Filtrar las filas para mantener consistencia con entrenamiento

    # **Paso 1: Imputación y transformación de columnas específicas**
    df['employment_status'] = df['employment_status'].fillna('Unemployed')
    df[['employment_industry', 'employment_occupation']] = df[['employment_industry', 'employment_occupation']].mask(
        df['employment_status'].isin(['Not in Labor Force', 'Unemployed']), 'Missing'
    )
    df['health_insurance_Missing'] = df['health_insurance'].isna().astype(int)
    df['health_insurance'] = df['health_insurance'].fillna(0).astype(int)

    # **Paso 2: Imputación personalizada**
    ordinal_cols = ['h1n1_concern', 'h1n1_knowledge', 'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk',
                    'opinion_h1n1_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 
                    'opinion_seas_sick_from_vacc']
    for col in ordinal_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')
        max_value = df[col].max()
        df[col] = df[col].fillna(max_value + 1)

    ordinal_order = {
        'age_group': ['18 - 34 Years', '35 - 44 Years', '45 - 54 Years', '55 - 64 Years', '65+ Years'],
        'education': ['< 12 Years', '12 Years', 'Some College', 'College Graduate', 'Missing'],
        'income_poverty': ['Below Poverty', '<= $75,000, Above Poverty', '> $75,000', 'Missing']
    }
    for col, order in ordinal_order.items():
        df[col] = df[col].fillna('Missing')
        df[col] = pd.Categorical(df[col], categories=order, ordered=True).codes

    binary_cols = [
        'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask',
        'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home',
        'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
        'chronic_med_condition', 'child_under_6_months', 'health_worker'
    ]
    for col in binary_cols:
        df[col] = df[col].fillna(df[col].mean()).round(0).astype(int)

    binary_cols_str = ['sex', 'marital_status', 'rent_or_own']
    mappings = {
        'sex': {'Male': 0, 'Female': 1},
        'marital_status': {'Not Married': 0, 'Married': 1},
        'rent_or_own': {'Own': 0, 'Rent': 1}
    }
    for col, mapping in mappings.items():
        df[col] = df[col].fillna('Missing')
        df[col] = df[col].map(mapping).fillna(-1).astype(int)

    nominal_cols = ['race', 'employment_status', 'hhs_geo_region', 'census_msa', 
                    'employment_industry', 'employment_occupation']
    for col in nominal_cols:
        df[col] = df[col].fillna('Missing')

    one_hot_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
    nominal_encoded = one_hot_encoder.fit_transform(df[nominal_cols])
    nominal_encoded_df = pd.DataFrame(
        nominal_encoded,
        columns=one_hot_encoder.get_feature_names_out(nominal_cols),
        index=df.index
    )

    numeric_cols = ['household_adults', 'household_children']
    imputer = KNNImputer(n_neighbors=5)
    df[numeric_cols] = imputer.fit_transform(df[numeric_cols])
    df[numeric_cols] = df[numeric_cols].round(0).astype(int)

    df.drop(columns=nominal_cols, inplace=True)
    df = pd.concat([df, nominal_encoded_df], axis=1)

    return df, indices_to_keep

# %%
X_train_preprocessed, indices_to_keep_train = preprocess_data(X_train.copy())
X_test_preprocessed, indices_to_keep_test = preprocess_data(X_test.copy())

# %%
X_train_preprocessed.to_csv('preprocessed_X_train.csv', index=True)
X_test_preprocessed.to_csv('preprocessed_X_test.csv', index=True)
y_train.loc[indices_to_keep_train].to_csv('preprocessed_y_train.csv', index=True)
y_test.loc[indices_to_keep_test].to_csv('preprocessed_y_test.csv', index=True)

# %%
print(X_train_preprocessed.columns)
# Out:
# Index(['h1n1_concern', 'h1n1_knowledge', 'behavioral_antiviral_meds',
#        'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk',
#        'opinion_h1n1_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
#        'education', 'sex', 'income_poverty', 'marital_status', 'rent_or_own',
#        'household_adults', 'household_children', 'health_insurance_Missing',
#        'race_Black', 'race_Hispanic', 'race_Other or Multiple', 'race_White',
#        'employment_status_Employed', 'employment_status_Not in Labor Force',
#        'employment_status_Unemployed', 'hhs_geo_region_atmpeygn',
#        'hhs_geo_region_bhuqouqj', 'hhs_geo_region_dqpwygqj',
#        'hhs_geo_region_fpwskwrf', 'hhs_geo_region_kbazzjca',
#        'hhs_geo_region_lrircsnp', 'hhs_geo_region_lzgpxyit',
#        'hhs_geo_region_mlyzmhmf', 'hhs_geo_region_oxchjgsf',
#        'hhs_geo_region_qufhixun', 'census_msa_MSA, Not Principle  City',
#        'census_msa_MSA, Principle City', 'census_msa_Non-MSA',
#        'employment_industry_Missing', 'employment_industry_arjwrbjb',
#        'employment_industry_atmlpfrs', 'employment_industry_cfqqtusy',
#        'employment_industry_dotnnunm', 'employment_industry_fcxhlnwr',
#        'employment_industry_haxffmxo', 'employment_industry_ldnlellj',
#        'employment_industry_mcubkhph', 'employment_industry_mfikgejo',
#        'employment_industry_msuufmds', 'employment_industry_nduyfdeo',
#        'employment_industry_phxvnwax', 'employment_industry_pxcmvdjn',
#        'employment_industry_qnlwzans', 'employment_industry_rucpziij',
#        'employment_industry_saaquncn', 'employment_industry_vjjrobsf',
#        'employment_industry_wlfvacwt', 'employment_industry_wxleyezf',
#        'employment_industry_xicduogh', 'employment_industry_xqicxuve',
#        'employment_occupation_Missing', 'employment_occupation_bxpfxfdn',
#        'employment_occupation_ccgxvspp', 'employment_occupation_cmhcxjea',
#        'employment_occupation_dcjcmpih', 'employment_occupation_dlvbwzss',
#        'employment_occupation_emcorrxb', 'employment_occupation_haliazsg',
#        'employment_occupation_hfxkjkmi', 'employment_occupation_hodpvpew',
#        'employment_occupation_kldqjyjy', 'employment_occupation_mxkfnird',
#        'employment_occupation_oijqvulv', 'employment_occupation_pvmttkik',
#        'employment_occupation_qxajmpny', 'employment_occupation_rcertsgn',
#        'employment_occupation_tfqavkke', 'employment_occupation_ukymxvdu',
#        'employment_occupation_uqqtjvyb', 'employment_occupation_vlluhbov',
#        'employment_occupation_xgwztkwe', 'employment_occupation_xqwwgdyp',
#        'employment_occupation_xtkaffoo', 'employment_occupation_xzmlyyjv'],
#       dtype='object')

# %%
# Cargar el conjunto de prueba externo y preprocesar
test_set_features = pd.read_csv("Data/test_set_features.csv", index_col="respondent_id")
test_set_preprocessed, indices_to_keep_test_2 = preprocess_data(test_set_features.copy(), is_train=False)

# Guardar el conjunto de prueba preprocesado
test_set_preprocessed.to_csv("Data/preprocessed_test_set_features.csv", index=True)

# %%
print(X_train_preprocessed.isnull().sum())
# Out:
# h1n1_concern                      0
# h1n1_knowledge                    0
# behavioral_antiviral_meds         0
# behavioral_avoidance              0
# behavioral_face_mask              0
#                                  ..
# employment_occupation_vlluhbov    0
# employment_occupation_xgwztkwe    0
# employment_occupation_xqwwgdyp    0
# employment_occupation_xtkaffoo    0
# employment_occupation_xzmlyyjv    0
# Length: 96, dtype: int64

# %%
print(X_train_preprocessed.shape)
print(y_train.loc[indices_to_keep_train].shape)
print(X_test_preprocessed.shape)
print(y_test.loc[indices_to_keep_test].shape)
# Out:
# (21205, 96)
# (21205, 2)
# (5296, 96)
# (5296, 2)

# %%
# 1. Dimensiones del dataset
print("Dimensiones del dataset:")
print(f"Filas: {X_train_preprocessed.shape[0]}, Columnas: {X_train_preprocessed.shape[1]}")

# 2. Información del dataset
print("\nInformación general del dataset:")
print(X_train_preprocessed.info())

# 3. Valores faltantes
print("\nValores faltantes por columna (porcentaje):")
missing_values = X_train_preprocessed.isna().mean() * 100
print(missing_values[missing_values > 0])

# 4. Estadísticas descriptivas
print("\nEstadísticas descriptivas del dataset:")
print(X_train_preprocessed.describe())

# 5. Distribución de las variables categóricas (opcional)
print("\nDistribución de algunas variables categóricas:")
categorical_cols = [col for col in X_train_preprocessed.columns if X_train_preprocessed[col].dtype == 'object']
for col in categorical_cols:
    print(f"\nDistribución de '{col}':")
    print(X_train_preprocessed[col].value_counts(normalize=True) * 100)
# Out:
# Dimensiones del dataset:
# Filas: 21205, Columnas: 96
#
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21205 entries, 12230 to 467
# Data columns (total 96 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   h1n1_concern                          21205 non-null  float64
#  1   h1n1_knowledge                        21205 non-null  float64
#  2   behavioral_antiviral_meds             21205 non-null  int32
#  3   behavioral_avoidance                  21205 non-null  int32
#  4   behavioral_face_mask                  21205 non-null  int32
#  5   behavioral_wash_hands                 21205 non-null  int32
#  6   behavioral_large_gatherings           21205 non-null  int32
#  7   behavioral_outside_home               21205 non-null  int32
#  8   behavioral_touch_face                 21205 non-null  int32
#  9   doctor_recc_h1n1                      21205 non-null  int32
#  10  doctor_recc_seasonal                  21205 non-null  int32
#  11  chronic_med_condition                 21205 non-null  int32
#  12  child_under_6_months                  21205 non-null  int32
#  13  health_worker                         21205 non-null  int32
#  14  health_insurance                      21205 non-null  int32
#  15  opinion_h1n1_vacc_effective           21205 non-null  float64
#  16  opinion_h1n1_risk                     21205 non-null  float64
#  17  opinion_h1n1_sick_from_vacc           21205 non-null  float64
#  18  opinion_seas_vacc_effective           21205 non-null  float64
#  19  opinion_seas_risk                     21205 non-null  float64
#  20  opinion_seas_sick_from_vacc           21205 non-null  float64
#  21  age_group                             21205 non-null  int8
#  22  education                             21205 non-null  int8
#  23  sex                                   21205 non-null  int32
#  24  income_poverty                        21205 non-null  int8
#  25  marital_status                        21205 non-null  int32
#  26  rent_or_own                           21205 non-null  int32
#  27  household_adults                      21205 non-null  int32
#  28  household_children                    21205 non-null  int32
#  29  health_insurance_Missing              21205 non-null  int32
#  30  race_Black                            21205 non-null  float64
#  31  race_Hispanic                         21205 non-null  float64
#  32  race_Other or Multiple                21205 non-null  float64
#  33  race_White                            21205 non-null  float64
#  34  employment_status_Employed            21205 non-null  float64
#  35  employment_status_Not in Labor Force  21205 non-null  float64
#  36  employment_status_Unemployed          21205 non-null  float64
#  37  hhs_geo_region_atmpeygn               21205 non-null  float64
#  38  hhs_geo_region_bhuqouqj               21205 non-null  float64
#  39  hhs_geo_region_dqpwygqj               21205 non-null  float64
#  40  hhs_geo_region_fpwskwrf               21205 non-null  float64
#  41  hhs_geo_region_kbazzjca               21205 non-null  float64
#  42  hhs_geo_region_lrircsnp               21205 non-null  float64
#  43  hhs_geo_region_lzgpxyit               21205 non-null  float64
#  44  hhs_geo_region_mlyzmhmf               21205 non-null  float64
#  45  hhs_geo_region_oxchjgsf               21205 non-null  float64
#  46  hhs_geo_region_qufhixun               21205 non-null  float64
#  47  census_msa_MSA, Not Principle  City   21205 non-null  float64
#  48  census_msa_MSA, Principle City        21205 non-null  float64
#  49  census_msa_Non-MSA                    21205 non-null  float64
#  50  employment_industry_Missing           21205 non-null  float64
#  51  employment_industry_arjwrbjb          21205 non-null  float64
#  52  employment_industry_atmlpfrs          21205 non-null  float64
#  53  employment_industry_cfqqtusy          21205 non-null  float64
#  54  employment_industry_dotnnunm          21205 non-null  float64
#  55  employment_industry_fcxhlnwr          21205 non-null  float64
#  56  employment_industry_haxffmxo          21205 non-null  float64
#  57  employment_industry_ldnlellj          21205 non-null  float64
#  58  employment_industry_mcubkhph          21205 non-null  float64
#  59  employment_industry_mfikgejo          21205 non-null  float64
#  60  employment_industry_msuufmds          21205 non-null  float64
#  61  employment_industry_nduyfdeo          21205 non-null  float64
#  62  employment_industry_phxvnwax          21205 non-null  float64
#  63  employment_industry_pxcmvdjn          21205 non-null  float64
#  64  employment_industry_qnlwzans          21205 non-null  float64
#  65  employment_industry_rucpziij          21205 non-null  float64
#  66  employment_industry_saaquncn          21205 non-null  float64
#  67  employment_industry_vjjrobsf          21205 non-null  float64
#  68  employment_industry_wlfvacwt          21205 non-null  float64
#  69  employment_industry_wxleyezf          21205 non-null  float64
#  70  employment_industry_xicduogh          21205 non-null  float64
#  71  employment_industry_xqicxuve          21205 non-null  float64
#  72  employment_occupation_Missing         21205 non-null  float64
#  73  employment_occupation_bxpfxfdn        21205 non-null  float64
#  74  employment_occupation_ccgxvspp        21205 non-null  float64
#  75  employment_occupation_cmhcxjea        21205 non-null  float64
#  76  employment_occupation_dcjcmpih        21205 non-null  float64
#  77  employment_occupation_dlvbwzss        21205 non-null  float64
#  78  employment_occupation_emcorrxb        21205 non-null  float64
#  79  employment_occupation_haliazsg        21205 non-null  float64
#  80  employment_occupation_hfxkjkmi        21205 non-null  float64
#  81  employment_occupation_hodpvpew        21205 non-null  float64
#  82  employment_occupation_kldqjyjy        21205 non-null  float64
#  83  employment_occupation_mxkfnird        21205 non-null  float64
#  84  employment_occupation_oijqvulv        21205 non-null  float64
#  85  employment_occupation_pvmttkik        21205 non-null  float64
#  86  employment_occupation_qxajmpny        21205 non-null  float64
#  87  employment_occupation_rcertsgn        21205 non-null  float64
#  88  employment_occupation_tfqavkke        21205 non-null  float64
#  89  employment_occupation_ukymxvdu        21205 non-null  float64
#  90  employment_occupation_uqqtjvyb        21205 non-null  float64
#  91  employment_occupation_vlluhbov        21205 non-null  float64
#  92  employment_occupation_xgwztkwe        21205 non-null  float64
#  93  employment_occupation_xqwwgdyp        21205 non-null  float64
#  94  employment_occupation_xtkaffoo        21205 non-null  float64
#  95  employment_occupation_xzmlyyjv        21205 non-null  float64
# dtypes: float64(74), int32(19), int8(3)
# memory usage: 13.7 MB
# None
#
# Valores faltantes por columna (porcentaje):
# Series([], dtype: float64)
#
# Estadísticas descriptivas del dataset:
#        h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# count  21205.000000    21205.000000               21205.000000
# mean       1.625088        1.272813                   0.048526
# std        0.918625        0.624395                   0.214881
# min        0.000000        0.000000                   0.000000
# 25%        1.000000        1.000000                   0.000000
# 50%        2.000000        1.000000                   0.000000
# 75%        2.000000        2.000000                   0.000000
# max        4.000000        3.000000                   1.000000
#
#        behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# count          21205.000000          21205.000000           21205.000000
# mean               0.728555              0.070078               0.825466
# std                0.444716              0.255284               0.379577
# min                0.000000              0.000000               0.000000
# 25%                0.000000              0.000000               1.000000
# 50%                1.000000              0.000000               1.000000
# 75%                1.000000              0.000000               1.000000
# max                1.000000              1.000000               1.000000
#
#        behavioral_large_gatherings  behavioral_outside_home  \
# count                 21205.000000             21205.000000
# mean                      0.353973                 0.332610
# std                       0.478212                 0.471159
# min                       0.000000                 0.000000
# 25%                       0.000000                 0.000000
# 50%                       0.000000                 0.000000
# 75%                       1.000000                 1.000000
# max                       1.000000                 1.000000
#
#        behavioral_touch_face  doctor_recc_h1n1  ...  \
# count           21205.000000      21205.000000  ...
# mean                0.677293          0.202877  ...
# std                 0.467523          0.402151  ...
# min                 0.000000          0.000000  ...
# 25%                 0.000000          0.000000  ...
# 50%                 1.000000          0.000000  ...
# 75%                 1.000000          0.000000  ...
# max                 1.000000          1.000000  ...
#
#        employment_occupation_qxajmpny  employment_occupation_rcertsgn  \
# count                    21205.000000                    21205.000000
# mean                         0.020844                        0.010422
# std                          0.142866                        0.101558
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_tfqavkke  employment_occupation_ukymxvdu  \
# count                    21205.000000                    21205.000000
# mean                         0.014242                        0.014431
# std                          0.118489                        0.119260
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_uqqtjvyb  employment_occupation_vlluhbov  \
# count                    21205.000000                    21205.000000
# mean                         0.016788                        0.013582
# std                          0.128481                        0.115749
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_xgwztkwe  employment_occupation_xqwwgdyp  \
# count                    21205.000000                    21205.000000
# mean                         0.040745                        0.017590
# std                          0.197704                        0.131459
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
#        employment_occupation_xtkaffoo  employment_occupation_xzmlyyjv
# count                    21205.000000                    21205.000000
# mean                         0.067626                        0.009102
# std                          0.251108                        0.094970
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          0.000000                        0.000000
# max                          1.000000                        1.000000
#
# [8 rows x 96 columns]
#
# Distribución de algunas variables categóricas:

# %%
# 6. Correlación entre variables (opcional)
print("\nMatriz de correlación:")
correlation_matrix = X_train_preprocessed.corr()
print(correlation_matrix)

# Visualización opcional de correlaciones altas
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Matriz de correlación del dataset preprocesado")
plt.show()
# Out:
# Matriz de correlación:
#                                 h1n1_concern  h1n1_knowledge  \
# h1n1_concern                        1.000000        0.055817
# h1n1_knowledge                      0.055817        1.000000
# behavioral_antiviral_meds           0.087870       -0.011503
# behavioral_avoidance                0.221418        0.080897
# behavioral_face_mask                0.155477        0.030948
# ...                                      ...             ...
# employment_occupation_vlluhbov      0.016843       -0.038219
# employment_occupation_xgwztkwe     -0.023650        0.016156
# employment_occupation_xqwwgdyp      0.003063       -0.033760
# employment_occupation_xtkaffoo     -0.016637        0.070020
# employment_occupation_xzmlyyjv     -0.010618        0.031293
#
#                                 behavioral_antiviral_meds  \
# h1n1_concern                                     0.087870
# h1n1_knowledge                                  -0.011503
# behavioral_antiviral_meds                        1.000000
# behavioral_avoidance                             0.046054
# behavioral_face_mask                             0.146919
# ...                                                   ...
# employment_occupation_vlluhbov                   0.030384
# employment_occupation_xgwztkwe                   0.006742
# employment_occupation_xqwwgdyp                   0.019867
# employment_occupation_xtkaffoo                  -0.013623
# employment_occupation_xzmlyyjv                  -0.010089
#
#                                 behavioral_avoidance  behavioral_face_mask  \
# h1n1_concern                                0.221418              0.155477
# h1n1_knowledge                              0.080897              0.030948
# behavioral_antiviral_meds                   0.046054              0.146919
# behavioral_avoidance                        1.000000              0.061218
# behavioral_face_mask                        0.061218              1.000000
# ...                                              ...                   ...
# employment_occupation_vlluhbov             -0.000755              0.022053
# employment_occupation_xgwztkwe              0.002966             -0.026675
# employment_occupation_xqwwgdyp             -0.014319             -0.010032
# employment_occupation_xtkaffoo              0.013199             -0.028318
# employment_occupation_xzmlyyjv             -0.002916             -0.004912
#
#                                 behavioral_wash_hands  \
# h1n1_concern                                 0.278275
# h1n1_knowledge                               0.081521
# behavioral_antiviral_meds                    0.062213
# behavioral_avoidance                         0.328660
# behavioral_face_mask                         0.081453
# ...                                               ...
# employment_occupation_vlluhbov               0.004579
# employment_occupation_xgwztkwe              -0.004526
# employment_occupation_xqwwgdyp              -0.001795
# employment_occupation_xtkaffoo              -0.002334
# employment_occupation_xzmlyyjv              -0.006953
#
#                                 behavioral_large_gatherings  \
# h1n1_concern                                       0.248429
# h1n1_knowledge                                    -0.046078
# behavioral_antiviral_meds                          0.106367
# behavioral_avoidance                               0.223636
# behavioral_face_mask                               0.179247
# ...                                                     ...
# employment_occupation_vlluhbov                     0.023904
# employment_occupation_xgwztkwe                    -0.043813
# employment_occupation_xqwwgdyp                     0.015730
# employment_occupation_xtkaffoo                    -0.050505
# employment_occupation_xzmlyyjv                    -0.038751
#
#                                 behavioral_outside_home  \
# h1n1_concern                                   0.241379
# h1n1_knowledge                                -0.066873
# behavioral_antiviral_meds                      0.127981
# behavioral_avoidance                           0.217988
# behavioral_face_mask                           0.161833
# ...                                                 ...
# employment_occupation_vlluhbov                 0.024393
# employment_occupation_xgwztkwe                -0.042212
# employment_occupation_xqwwgdyp                 0.022794
# employment_occupation_xtkaffoo                -0.054596
# employment_occupation_xzmlyyjv                -0.041309
#
#                                 behavioral_touch_face  doctor_recc_h1n1  ...  \
# h1n1_concern                                 0.240536          0.132877  ...
# h1n1_knowledge                               0.078655          0.090219  ...
# behavioral_antiviral_meds                    0.067630          0.047066  ...
# behavioral_avoidance                         0.325158          0.066916  ...
# behavioral_face_mask                         0.104532          0.078335  ...
# ...                                               ...               ...  ...
# employment_occupation_vlluhbov               0.003433         -0.011579  ...
# employment_occupation_xgwztkwe              -0.011317         -0.018558  ...
# employment_occupation_xqwwgdyp              -0.006622         -0.030039  ...
# employment_occupation_xtkaffoo              -0.023797         -0.006036  ...
# employment_occupation_xzmlyyjv              -0.018819         -0.019949  ...
#
#                                 employment_occupation_qxajmpny  \
# h1n1_concern                                         -0.022383
# h1n1_knowledge                                       -0.050005
# behavioral_antiviral_meds                             0.020818
# behavioral_avoidance                                 -0.027480
# behavioral_face_mask                                 -0.003846
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.017120
# employment_occupation_xgwztkwe                       -0.030070
# employment_occupation_xqwwgdyp                       -0.019523
# employment_occupation_xtkaffoo                       -0.039294
# employment_occupation_xzmlyyjv                       -0.013983
#
#                                 employment_occupation_rcertsgn  \
# h1n1_concern                                         -0.028382
# h1n1_knowledge                                       -0.015091
# behavioral_antiviral_meds                             0.002757
# behavioral_avoidance                                 -0.018807
# behavioral_face_mask                                 -0.020896
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.012042
# employment_occupation_xgwztkwe                       -0.021151
# employment_occupation_xqwwgdyp                       -0.013732
# employment_occupation_xtkaffoo                       -0.027638
# employment_occupation_xzmlyyjv                       -0.009836
#
#                                 employment_occupation_tfqavkke  \
# h1n1_concern                                          0.005729
# h1n1_knowledge                                       -0.040407
# behavioral_antiviral_meds                             0.017310
# behavioral_avoidance                                 -0.008076
# behavioral_face_mask                                  0.005982
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.014104
# employment_occupation_xgwztkwe                       -0.024773
# employment_occupation_xqwwgdyp                       -0.016084
# employment_occupation_xtkaffoo                       -0.032371
# employment_occupation_xzmlyyjv                       -0.011520
#
#                                 employment_occupation_ukymxvdu  \
# h1n1_concern                                         -0.020352
# h1n1_knowledge                                        0.030728
# behavioral_antiviral_meds                            -0.018125
# behavioral_avoidance                                 -0.004391
# behavioral_face_mask                                 -0.009982
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.014199
# employment_occupation_xgwztkwe                       -0.024938
# employment_occupation_xqwwgdyp                       -0.016191
# employment_occupation_xtkaffoo                       -0.032588
# employment_occupation_xzmlyyjv                       -0.011597
#
#                                 employment_occupation_uqqtjvyb  \
# h1n1_concern                                         -0.017394
# h1n1_knowledge                                       -0.039459
# behavioral_antiviral_meds                             0.016612
# behavioral_avoidance                                 -0.017635
# behavioral_face_mask                                  0.000075
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.015333
# employment_occupation_xgwztkwe                       -0.026931
# employment_occupation_xqwwgdyp                       -0.017485
# employment_occupation_xtkaffoo                       -0.035192
# employment_occupation_xzmlyyjv                       -0.012524
#
#                                 employment_occupation_vlluhbov  \
# h1n1_concern                                          0.016843
# h1n1_knowledge                                       -0.038219
# behavioral_antiviral_meds                             0.030384
# behavioral_avoidance                                 -0.000755
# behavioral_face_mask                                  0.022053
# ...                                                        ...
# employment_occupation_vlluhbov                        1.000000
# employment_occupation_xgwztkwe                       -0.024183
# employment_occupation_xqwwgdyp                       -0.015701
# employment_occupation_xtkaffoo                       -0.031601
# employment_occupation_xzmlyyjv                       -0.011246
#
#                                 employment_occupation_xgwztkwe  \
# h1n1_concern                                         -0.023650
# h1n1_knowledge                                        0.016156
# behavioral_antiviral_meds                             0.006742
# behavioral_avoidance                                  0.002966
# behavioral_face_mask                                 -0.026675
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.024183
# employment_occupation_xgwztkwe                        1.000000
# employment_occupation_xqwwgdyp                       -0.027578
# employment_occupation_xtkaffoo                       -0.055505
# employment_occupation_xzmlyyjv                       -0.019752
#
#                                 employment_occupation_xqwwgdyp  \
# h1n1_concern                                          0.003063
# h1n1_knowledge                                       -0.033760
# behavioral_antiviral_meds                             0.019867
# behavioral_avoidance                                 -0.014319
# behavioral_face_mask                                 -0.010032
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.015701
# employment_occupation_xgwztkwe                       -0.027578
# employment_occupation_xqwwgdyp                        1.000000
# employment_occupation_xtkaffoo                       -0.036037
# employment_occupation_xzmlyyjv                       -0.012824
#
#                                 employment_occupation_xtkaffoo  \
# h1n1_concern                                         -0.016637
# h1n1_knowledge                                        0.070020
# behavioral_antiviral_meds                            -0.013623
# behavioral_avoidance                                  0.013199
# behavioral_face_mask                                 -0.028318
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.031601
# employment_occupation_xgwztkwe                       -0.055505
# employment_occupation_xqwwgdyp                       -0.036037
# employment_occupation_xtkaffoo                        1.000000
# employment_occupation_xzmlyyjv                       -0.025811
#
#                                 employment_occupation_xzmlyyjv
# h1n1_concern                                         -0.010618
# h1n1_knowledge                                        0.031293
# behavioral_antiviral_meds                            -0.010089
# behavioral_avoidance                                 -0.002916
# behavioral_face_mask                                 -0.004912
# ...                                                        ...
# employment_occupation_vlluhbov                       -0.011246
# employment_occupation_xgwztkwe                       -0.019752
# employment_occupation_xqwwgdyp                       -0.012824
# employment_occupation_xtkaffoo                       -0.025811
# employment_occupation_xzmlyyjv                        1.000000
#
# [96 rows x 96 columns]

# %% [markdown]
# Es obvio que una vez se han codificado todas las variables, resulta casi imposible distinguir correctamente las correlaciones entre variables
